# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline


# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1_l2

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_l2_ratio=1e-8, drp_ratio=0.2):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    x = keras.layers.BatchNormalization()(input_layer)
    
    for i, n_units in enumerate(num_neurons):
        x = keras.layers.Dense(units=n_units, 
                               activation="relu", 
                               name="hidden_layer"+str(i+1),
                               kernel_regularizer=l1_l2(l1_l2_ratio))(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-4
EPOCHS = 80
BATCH_SIZE = 256

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: Earlystop
"""
from keras.callbacks import EarlyStopping

earlystop = EarlyStopping(monitor="val_accuracy", 
                          patience=25, 
                          verbose=1
                          )

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
keras.backend.clear_session() # 把舊的 Graph 清掉

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[earlystop])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Epoch 1/80
# 196/196 [==============================] - 2s 11ms/step - loss: 15.1302 - accuracy: 0.2926 - val_loss: 13.7338 - val_accuracy: 0.3423
# Epoch 2/80
# 196/196 [==============================] - 2s 10ms/step - loss: 12.7028 - accuracy: 0.3778 - val_loss: 11.4609 - val_accuracy: 0.4319
# Epoch 3/80
# 196/196 [==============================] - 2s 10ms/step - loss: 10.6580 - accuracy: 0.4111 - val_loss: 9.5905 - val_accuracy: 0.4704
# Epoch 4/80
# 196/196 [==============================] - 2s 10ms/step - loss: 8.9561 - accuracy: 0.4356 - val_loss: 8.0833 - val_accuracy: 0.4825
# Epoch 5/80
# 196/196 [==============================] - 2s 10ms/step - loss: 7.5647 - accuracy: 0.4542 - val_loss: 6.8512 - val_accuracy: 0.4980
# Epoch 6/80
# 196/196 [==============================] - 2s 10ms/step - loss: 6.4414 - accuracy: 0.4688 - val_loss: 5.8834 - val_accuracy: 0.4949
# Epoch 7/80
# 196/196 [==============================] - 2s 10ms/step - loss: 5.5400 - accuracy: 0.4843 - val_loss: 5.0847 - val_accuracy: 0.5139
# Epoch 8/80
# 196/196 [==============================] - 2s 10ms/step - loss: 4.8219 - accuracy: 0.4960 - val_loss: 4.4516 - val_accuracy: 0.5184
# Epoch 9/80
# 196/196 [==============================] - 2s 10ms/step - loss: 4.2306 - accuracy: 0.5058 - val_loss: 3.9419 - val_accuracy: 0.5204
# Epoch 10/80
# 196/196 [==============================] - 2s 10ms/step - loss: 3.7674 - accuracy: 0.5102 - val_loss: 3.5274 - val_accuracy: 0.5284
# Epoch 11/80
# 196/196 [==============================] - 2s 10ms/step - loss: 3.3782 - accuracy: 0.5235 - val_loss: 3.1904 - val_accuracy: 0.5343
# Epoch 12/80
# 196/196 [==============================] - 2s 10ms/step - loss: 3.0634 - accuracy: 0.5324 - val_loss: 2.9207 - val_accuracy: 0.5347
# Epoch 13/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.8073 - accuracy: 0.5397 - val_loss: 2.7039 - val_accuracy: 0.5430
# Epoch 14/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.5913 - accuracy: 0.5476 - val_loss: 2.5142 - val_accuracy: 0.5447
# Epoch 15/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.4095 - accuracy: 0.5569 - val_loss: 2.3712 - val_accuracy: 0.5391
# Epoch 16/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.2626 - accuracy: 0.5617 - val_loss: 2.2353 - val_accuracy: 0.5514
# Epoch 17/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.1326 - accuracy: 0.5678 - val_loss: 2.1410 - val_accuracy: 0.5449
# Epoch 18/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.0316 - accuracy: 0.5710 - val_loss: 2.0510 - val_accuracy: 0.5511
# Epoch 19/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.9370 - accuracy: 0.5770 - val_loss: 1.9699 - val_accuracy: 0.5546
# Epoch 20/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.8573 - accuracy: 0.5825 - val_loss: 1.9196 - val_accuracy: 0.5492
# Epoch 21/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.7814 - accuracy: 0.5905 - val_loss: 1.8581 - val_accuracy: 0.5603
# Epoch 22/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.7205 - accuracy: 0.5992 - val_loss: 1.8259 - val_accuracy: 0.5509
# Epoch 23/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.6742 - accuracy: 0.5965 - val_loss: 1.7876 - val_accuracy: 0.5537
# Epoch 24/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.6143 - accuracy: 0.6104 - val_loss: 1.7517 - val_accuracy: 0.5581
# Epoch 25/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.5825 - accuracy: 0.6084 - val_loss: 1.7019 - val_accuracy: 0.5598
# Epoch 26/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.5385 - accuracy: 0.6138 - val_loss: 1.6820 - val_accuracy: 0.5616
# Epoch 27/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.5037 - accuracy: 0.6189 - val_loss: 1.6583 - val_accuracy: 0.5688
# Epoch 28/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.4758 - accuracy: 0.6244 - val_loss: 1.6540 - val_accuracy: 0.5636
# Epoch 29/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.4439 - accuracy: 0.6306 - val_loss: 1.6412 - val_accuracy: 0.5610
# Epoch 30/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.4196 - accuracy: 0.6304 - val_loss: 1.6258 - val_accuracy: 0.5633
# Epoch 31/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3973 - accuracy: 0.6346 - val_loss: 1.6199 - val_accuracy: 0.5585
# Epoch 32/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3708 - accuracy: 0.6416 - val_loss: 1.5842 - val_accuracy: 0.5677
# Epoch 33/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3490 - accuracy: 0.6478 - val_loss: 1.5922 - val_accuracy: 0.5683
# Epoch 34/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3300 - accuracy: 0.6505 - val_loss: 1.5712 - val_accuracy: 0.5709
# Epoch 35/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3090 - accuracy: 0.6555 - val_loss: 1.5929 - val_accuracy: 0.5578
# Epoch 36/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2997 - accuracy: 0.6578 - val_loss: 1.5844 - val_accuracy: 0.5563
# Epoch 37/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2853 - accuracy: 0.6602 - val_loss: 1.5697 - val_accuracy: 0.5646
# Epoch 38/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2745 - accuracy: 0.6628 - val_loss: 1.5727 - val_accuracy: 0.5710
# Epoch 39/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2511 - accuracy: 0.6702 - val_loss: 1.5676 - val_accuracy: 0.5682
# Epoch 40/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2425 - accuracy: 0.6717 - val_loss: 1.5576 - val_accuracy: 0.5733
# Epoch 41/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2246 - accuracy: 0.6764 - val_loss: 1.5420 - val_accuracy: 0.5743
# Epoch 42/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2191 - accuracy: 0.6786 - val_loss: 1.5763 - val_accuracy: 0.5620
# Epoch 43/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2029 - accuracy: 0.6805 - val_loss: 1.5635 - val_accuracy: 0.5685
# Epoch 44/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1966 - accuracy: 0.6864 - val_loss: 1.5809 - val_accuracy: 0.5642
# Epoch 45/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1942 - accuracy: 0.6848 - val_loss: 1.5692 - val_accuracy: 0.5708
# Epoch 46/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1847 - accuracy: 0.6876 - val_loss: 1.5500 - val_accuracy: 0.5728
# Epoch 47/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1744 - accuracy: 0.6908 - val_loss: 1.5860 - val_accuracy: 0.5634
# Epoch 48/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1667 - accuracy: 0.6933 - val_loss: 1.5638 - val_accuracy: 0.5707
# Epoch 49/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1492 - accuracy: 0.6994 - val_loss: 1.5825 - val_accuracy: 0.5611
# Epoch 50/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1529 - accuracy: 0.6968 - val_loss: 1.5753 - val_accuracy: 0.5673
# Epoch 51/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1394 - accuracy: 0.7032 - val_loss: 1.5793 - val_accuracy: 0.5643
# Epoch 52/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1313 - accuracy: 0.7055 - val_loss: 1.5861 - val_accuracy: 0.5687
# Epoch 53/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1266 - accuracy: 0.7085 - val_loss: 1.5733 - val_accuracy: 0.5694
# Epoch 54/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1212 - accuracy: 0.7113 - val_loss: 1.5848 - val_accuracy: 0.5718
# Epoch 55/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1073 - accuracy: 0.7137 - val_loss: 1.5972 - val_accuracy: 0.5688
# Epoch 56/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1089 - accuracy: 0.7146 - val_loss: 1.6037 - val_accuracy: 0.5670
# Epoch 57/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0977 - accuracy: 0.7168 - val_loss: 1.5964 - val_accuracy: 0.5687
# Epoch 58/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0910 - accuracy: 0.7219 - val_loss: 1.5865 - val_accuracy: 0.5725
# Epoch 59/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0937 - accuracy: 0.7188 - val_loss: 1.5821 - val_accuracy: 0.5787
# Epoch 60/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0855 - accuracy: 0.7227 - val_loss: 1.5937 - val_accuracy: 0.5726
# Epoch 61/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0825 - accuracy: 0.7223 - val_loss: 1.5881 - val_accuracy: 0.5749
# Epoch 62/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0800 - accuracy: 0.7250 - val_loss: 1.6109 - val_accuracy: 0.5682
# Epoch 63/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0743 - accuracy: 0.7289 - val_loss: 1.6037 - val_accuracy: 0.5687
# Epoch 64/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0631 - accuracy: 0.7329 - val_loss: 1.6250 - val_accuracy: 0.5661
# Epoch 65/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0653 - accuracy: 0.7300 - val_loss: 1.6168 - val_accuracy: 0.5751
# Epoch 66/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0696 - accuracy: 0.7294 - val_loss: 1.6266 - val_accuracy: 0.5661
# Epoch 67/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0597 - accuracy: 0.7354 - val_loss: 1.6191 - val_accuracy: 0.5689
# Epoch 68/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0518 - accuracy: 0.7374 - val_loss: 1.6272 - val_accuracy: 0.5778
# Epoch 69/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0544 - accuracy: 0.7349 - val_loss: 1.6295 - val_accuracy: 0.5721
# Epoch 70/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0481 - accuracy: 0.7386 - val_loss: 1.6467 - val_accuracy: 0.5654
# Epoch 71/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0451 - accuracy: 0.7407 - val_loss: 1.6406 - val_accuracy: 0.5639
# Epoch 72/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0459 - accuracy: 0.7406 - val_loss: 1.6324 - val_accuracy: 0.5750
# Epoch 73/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0426 - accuracy: 0.7438 - val_loss: 1.6360 - val_accuracy: 0.5692
# Epoch 74/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0331 - accuracy: 0.7463 - val_loss: 1.6364 - val_accuracy: 0.5753
# Epoch 75/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0303 - accuracy: 0.7469 - val_loss: 1.6232 - val_accuracy: 0.5742
# Epoch 76/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0274 - accuracy: 0.7480 - val_loss: 1.6364 - val_accuracy: 0.5697
# Epoch 77/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0251 - accuracy: 0.7497 - val_loss: 1.6489 - val_accuracy: 0.5694
# Epoch 78/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0274 - accuracy: 0.7498 - val_loss: 1.6700 - val_accuracy: 0.5709
# Epoch 79/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0243 - accuracy: 0.7511 - val_loss: 1.6386 - val_accuracy: 0.5745
# Epoch 80/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0169 - accuracy: 0.7541 - val_loss: 1.6578 - val_accuracy: 0.5727

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# # 作業
# ### 用 digits (dataset.load_digits()) 資料嘗試跑 t-SNE

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from sklearn import manifold, datasets

# %matplotlib inline

digits = datasets.load_digits()
X = digits.data
y = digits.target

# %%
n_samples, n_features = X.shape
n_neigbours = 30
tsne = manifold.TSNE(n_components = 2, random_state = 0, init = "pca", learning_rate = 200., early_exaggeration = 12.)

# %%
def plot_embedding(X, title = None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)
    
    plt.figure()
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                color = plt.cm.Set1(y[i] / 10),
                 fontdict = {"weight" : "bold", "size" : 9})
        
    if hasattr(offsetbox, "AnnotationBbox"):
        shown_images = np.array([[1., 1.]])
        for i in range(X.shape[0]):
            dist = np.sum((X[i] - shown_images) ** 2, 1)
            if np.min(dist) < 4e-3:
                continue
            shown_images = np.r_[shown_images, [X[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(digits.image[i], cmap = plt.cm.gray_r),
                X[i])
            ax.add_artist(imagebox)
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
        
print("computing t-SNE embedding")

X_tsne = tsne.fit_transform(X)

plot_embedding(X_tsne,
              "t-SNE embedding of the digits")

plt.show()
# Out:
# computing t-SNE embedding
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     104         try:
# --> 105             return self[key]
#     106         except KeyError:
#
# KeyError: 'image'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c70b3eebd0d6> in <module>
#      30
#      31 plot_embedding(X_tsne,
# ---> 32               "t-SNE embedding of the digits")
#      33
#      34 plt.show()
#
# <ipython-input-8-c70b3eebd0d6> in plot_embedding(X, title)
#      18             shown_images = np.r_[shown_images, [X[i]]]
#      19             imagebox = offsetbox.AnnotationBbox(
# ---> 20                 offsetbox.OffsetImage(digits.image[i], cmap = plt.cm.gray_r),
#      21                 X[i])
#      22             ax.add_artist(imagebox)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#     105             return self[key]
#     106         except KeyError:
# --> 107             raise AttributeError(key)
#     108
#     109     def __setstate__(self, state):
#
# AttributeError: image

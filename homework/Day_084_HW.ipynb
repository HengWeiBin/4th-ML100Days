# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1_l2

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_l2_ratio=1e-8, drp_ratio=0.2):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    x = keras.layers.BatchNormalization()(input_layer)
    
    for i, n_units in enumerate(num_neurons):
        x = keras.layers.Dense(units=n_units, 
                               activation="relu", 
                               name="hidden_layer"+str(i+1),
                               kernel_regularizer=l1_l2(l1_l2_ratio))(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-4
EPOCHS = 80
BATCH_SIZE = 256

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
keras.backend.clear_session() # 把舊的 Graph 清掉

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Epoch 1/80
# 196/196 [==============================] - 2s 11ms/step - loss: 15.1231 - accuracy: 0.2946 - val_loss: 13.7001 - val_accuracy: 0.3641
# Epoch 2/80
# 196/196 [==============================] - 2s 10ms/step - loss: 12.6948 - accuracy: 0.3748 - val_loss: 11.4342 - val_accuracy: 0.4414
# Epoch 3/80
# 196/196 [==============================] - 2s 10ms/step - loss: 10.6298 - accuracy: 0.4113 - val_loss: 9.5653 - val_accuracy: 0.4682
# Epoch 4/80
# 196/196 [==============================] - 2s 10ms/step - loss: 8.9220 - accuracy: 0.4368 - val_loss: 8.0429 - val_accuracy: 0.4851
# Epoch 5/80
# 196/196 [==============================] - 2s 9ms/step - loss: 7.5289 - accuracy: 0.4562 - val_loss: 6.8161 - val_accuracy: 0.4953
# Epoch 6/80
# 196/196 [==============================] - 2s 10ms/step - loss: 6.4001 - accuracy: 0.4736 - val_loss: 5.8474 - val_accuracy: 0.4983
# Epoch 7/80
# 196/196 [==============================] - 2s 10ms/step - loss: 5.5048 - accuracy: 0.4877 - val_loss: 5.0628 - val_accuracy: 0.5015
# Epoch 8/80
# 196/196 [==============================] - 2s 10ms/step - loss: 4.7904 - accuracy: 0.4960 - val_loss: 4.4282 - val_accuracy: 0.5075
# Epoch 9/80
# 196/196 [==============================] - 2s 10ms/step - loss: 4.2128 - accuracy: 0.5066 - val_loss: 3.9302 - val_accuracy: 0.5159
# Epoch 10/80
# 196/196 [==============================] - 2s 10ms/step - loss: 3.7439 - accuracy: 0.5148 - val_loss: 3.5207 - val_accuracy: 0.5249
# Epoch 11/80
# 196/196 [==============================] - 2s 10ms/step - loss: 3.3581 - accuracy: 0.5259 - val_loss: 3.1931 - val_accuracy: 0.5240
# Epoch 12/80
# 196/196 [==============================] - 2s 10ms/step - loss: 3.0532 - accuracy: 0.5342 - val_loss: 2.9121 - val_accuracy: 0.5337
# Epoch 13/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.8012 - accuracy: 0.5399 - val_loss: 2.7113 - val_accuracy: 0.5304
# Epoch 14/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.5888 - accuracy: 0.5497 - val_loss: 2.5327 - val_accuracy: 0.5369
# Epoch 15/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.4092 - accuracy: 0.5570 - val_loss: 2.3636 - val_accuracy: 0.5469
# Epoch 16/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.2590 - accuracy: 0.5637 - val_loss: 2.2497 - val_accuracy: 0.5439
# Epoch 17/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.1341 - accuracy: 0.5687 - val_loss: 2.1481 - val_accuracy: 0.5442
# Epoch 18/80
# 196/196 [==============================] - 2s 10ms/step - loss: 2.0260 - accuracy: 0.5717 - val_loss: 2.0684 - val_accuracy: 0.5450
# Epoch 19/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.9362 - accuracy: 0.5808 - val_loss: 1.9945 - val_accuracy: 0.5459
# Epoch 20/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.8545 - accuracy: 0.5872 - val_loss: 1.9297 - val_accuracy: 0.5468
# Epoch 21/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.7924 - accuracy: 0.5881 - val_loss: 1.8748 - val_accuracy: 0.5529
# Epoch 22/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.7232 - accuracy: 0.5950 - val_loss: 1.8781 - val_accuracy: 0.5363
# Epoch 23/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.6781 - accuracy: 0.5989 - val_loss: 1.7699 - val_accuracy: 0.5597
# Epoch 24/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.6206 - accuracy: 0.6063 - val_loss: 1.7657 - val_accuracy: 0.5561
# Epoch 25/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.5825 - accuracy: 0.6108 - val_loss: 1.7260 - val_accuracy: 0.5594
# Epoch 26/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.5478 - accuracy: 0.6126 - val_loss: 1.6943 - val_accuracy: 0.5570
# Epoch 27/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.5087 - accuracy: 0.6195 - val_loss: 1.6858 - val_accuracy: 0.5597
# Epoch 28/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.4775 - accuracy: 0.6255 - val_loss: 1.6388 - val_accuracy: 0.5718
# Epoch 29/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.4499 - accuracy: 0.6285 - val_loss: 1.6465 - val_accuracy: 0.5617
# Epoch 30/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.4245 - accuracy: 0.6327 - val_loss: 1.6168 - val_accuracy: 0.5629
# Epoch 31/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3936 - accuracy: 0.6385 - val_loss: 1.6097 - val_accuracy: 0.5618
# Epoch 32/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3767 - accuracy: 0.6441 - val_loss: 1.6049 - val_accuracy: 0.5673
# Epoch 33/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3585 - accuracy: 0.6466 - val_loss: 1.5988 - val_accuracy: 0.5614
# Epoch 34/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3353 - accuracy: 0.6501 - val_loss: 1.5867 - val_accuracy: 0.5633
# Epoch 35/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3185 - accuracy: 0.6533 - val_loss: 1.5810 - val_accuracy: 0.5612
# Epoch 36/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.3027 - accuracy: 0.6569 - val_loss: 1.5801 - val_accuracy: 0.5675
# Epoch 37/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2848 - accuracy: 0.6626 - val_loss: 1.5711 - val_accuracy: 0.5667
# Epoch 38/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2755 - accuracy: 0.6620 - val_loss: 1.5600 - val_accuracy: 0.5696
# Epoch 39/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2585 - accuracy: 0.6674 - val_loss: 1.5765 - val_accuracy: 0.5681
# Epoch 40/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2498 - accuracy: 0.6677 - val_loss: 1.5925 - val_accuracy: 0.5633
# Epoch 41/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2377 - accuracy: 0.6729 - val_loss: 1.5682 - val_accuracy: 0.5696
# Epoch 42/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2247 - accuracy: 0.6767 - val_loss: 1.5636 - val_accuracy: 0.5728
# Epoch 43/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2129 - accuracy: 0.6802 - val_loss: 1.5492 - val_accuracy: 0.5739
# Epoch 44/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.2041 - accuracy: 0.6818 - val_loss: 1.5820 - val_accuracy: 0.5694
# Epoch 45/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1920 - accuracy: 0.6852 - val_loss: 1.5719 - val_accuracy: 0.5684
# Epoch 46/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1871 - accuracy: 0.6888 - val_loss: 1.5510 - val_accuracy: 0.5719
# Epoch 47/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1787 - accuracy: 0.6879 - val_loss: 1.5902 - val_accuracy: 0.5583
# Epoch 48/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1681 - accuracy: 0.6921 - val_loss: 1.5546 - val_accuracy: 0.5697
# Epoch 49/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1585 - accuracy: 0.6963 - val_loss: 1.5858 - val_accuracy: 0.5627
# Epoch 50/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1475 - accuracy: 0.6994 - val_loss: 1.5611 - val_accuracy: 0.5749
# Epoch 51/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1512 - accuracy: 0.7007 - val_loss: 1.5750 - val_accuracy: 0.5732
# Epoch 52/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1358 - accuracy: 0.7063 - val_loss: 1.5584 - val_accuracy: 0.5765
# Epoch 53/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1320 - accuracy: 0.7057 - val_loss: 1.5775 - val_accuracy: 0.5715
# Epoch 54/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1121 - accuracy: 0.7095 - val_loss: 1.5751 - val_accuracy: 0.5711
# Epoch 55/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1239 - accuracy: 0.7082 - val_loss: 1.5932 - val_accuracy: 0.5663
# Epoch 56/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1142 - accuracy: 0.7120 - val_loss: 1.5863 - val_accuracy: 0.5714
# Epoch 57/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.1051 - accuracy: 0.7154 - val_loss: 1.5980 - val_accuracy: 0.5737
# Epoch 58/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0928 - accuracy: 0.7190 - val_loss: 1.6169 - val_accuracy: 0.5634
# Epoch 59/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0915 - accuracy: 0.7182 - val_loss: 1.5972 - val_accuracy: 0.5672
# Epoch 60/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0916 - accuracy: 0.7207 - val_loss: 1.6073 - val_accuracy: 0.5693
# Epoch 61/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0853 - accuracy: 0.7232 - val_loss: 1.6039 - val_accuracy: 0.5749
# Epoch 62/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0808 - accuracy: 0.7250 - val_loss: 1.5913 - val_accuracy: 0.5703
# Epoch 63/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0727 - accuracy: 0.7271 - val_loss: 1.6255 - val_accuracy: 0.5644
# Epoch 64/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0764 - accuracy: 0.7259 - val_loss: 1.6047 - val_accuracy: 0.5749
# Epoch 65/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0697 - accuracy: 0.7308 - val_loss: 1.6264 - val_accuracy: 0.5702
# Epoch 66/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0697 - accuracy: 0.7300 - val_loss: 1.6097 - val_accuracy: 0.5765
# Epoch 67/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0593 - accuracy: 0.7329 - val_loss: 1.6260 - val_accuracy: 0.5685
# Epoch 68/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0647 - accuracy: 0.7309 - val_loss: 1.6085 - val_accuracy: 0.5689
# Epoch 69/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0566 - accuracy: 0.7353 - val_loss: 1.6387 - val_accuracy: 0.5636
# Epoch 70/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0516 - accuracy: 0.7369 - val_loss: 1.6301 - val_accuracy: 0.5740
# Epoch 71/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0444 - accuracy: 0.7383 - val_loss: 1.6300 - val_accuracy: 0.5716
# Epoch 72/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0450 - accuracy: 0.7432 - val_loss: 1.6247 - val_accuracy: 0.5760
# Epoch 73/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0473 - accuracy: 0.7398 - val_loss: 1.6441 - val_accuracy: 0.5682
# Epoch 74/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0338 - accuracy: 0.7449 - val_loss: 1.6489 - val_accuracy: 0.5773
# Epoch 75/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0363 - accuracy: 0.7433 - val_loss: 1.6426 - val_accuracy: 0.5712
# Epoch 76/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0288 - accuracy: 0.7510 - val_loss: 1.6418 - val_accuracy: 0.5716
# Epoch 77/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0310 - accuracy: 0.7461 - val_loss: 1.6771 - val_accuracy: 0.5670
# Epoch 78/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0243 - accuracy: 0.7514 - val_loss: 1.6626 - val_accuracy: 0.5739
# Epoch 79/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0192 - accuracy: 0.7529 - val_loss: 1.6564 - val_accuracy: 0.5671
# Epoch 80/80
# 196/196 [==============================] - 2s 10ms/step - loss: 1.0182 - accuracy: 0.7504 - val_loss: 1.6460 - val_accuracy: 0.5765

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

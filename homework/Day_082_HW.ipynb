# %% [markdown]
# ## Work
# 1. 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# 2. 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = keras.layers.Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = keras.layers.Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-4
EPOCHS = 100
BATCH_SIZE = 512

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

keras.backend.clear_session() # 把舊的 Graph 清掉

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 98/98 [==============================] - 1s 11ms/step - loss: 2.1197 - accuracy: 0.2199 - val_loss: 1.9018 - val_accuracy: 0.3281
# Epoch 2/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.9157 - accuracy: 0.3081 - val_loss: 1.7974 - val_accuracy: 0.3686
# Epoch 3/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.8295 - accuracy: 0.3437 - val_loss: 1.7150 - val_accuracy: 0.3913
# Epoch 4/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.7733 - accuracy: 0.3658 - val_loss: 1.6703 - val_accuracy: 0.4174
# Epoch 5/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.7295 - accuracy: 0.3821 - val_loss: 1.6562 - val_accuracy: 0.4171
# Epoch 6/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.6970 - accuracy: 0.3968 - val_loss: 1.6082 - val_accuracy: 0.4359
# Epoch 7/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.6627 - accuracy: 0.4084 - val_loss: 1.5793 - val_accuracy: 0.4423
# Epoch 8/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.6370 - accuracy: 0.4193 - val_loss: 1.5624 - val_accuracy: 0.4498
# Epoch 9/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.6142 - accuracy: 0.4274 - val_loss: 1.5490 - val_accuracy: 0.4505
# Epoch 10/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5923 - accuracy: 0.4326 - val_loss: 1.5103 - val_accuracy: 0.4693
# Epoch 11/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5718 - accuracy: 0.4424 - val_loss: 1.4963 - val_accuracy: 0.4705
# Epoch 12/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5585 - accuracy: 0.4467 - val_loss: 1.4823 - val_accuracy: 0.4761
# Epoch 13/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5389 - accuracy: 0.4545 - val_loss: 1.4724 - val_accuracy: 0.4786
# Epoch 14/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5222 - accuracy: 0.4608 - val_loss: 1.4647 - val_accuracy: 0.4811
# Epoch 15/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.5104 - accuracy: 0.4665 - val_loss: 1.4513 - val_accuracy: 0.4826
# Epoch 16/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4928 - accuracy: 0.4715 - val_loss: 1.4526 - val_accuracy: 0.4866
# Epoch 17/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4822 - accuracy: 0.4750 - val_loss: 1.4300 - val_accuracy: 0.4982
# Epoch 18/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4613 - accuracy: 0.4838 - val_loss: 1.4217 - val_accuracy: 0.4952
# Epoch 19/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4457 - accuracy: 0.4870 - val_loss: 1.4232 - val_accuracy: 0.4969
# Epoch 20/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4353 - accuracy: 0.4921 - val_loss: 1.4439 - val_accuracy: 0.4822
# Epoch 21/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4272 - accuracy: 0.4951 - val_loss: 1.4020 - val_accuracy: 0.5012
# Epoch 22/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.4099 - accuracy: 0.5015 - val_loss: 1.3773 - val_accuracy: 0.5150
# Epoch 23/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3972 - accuracy: 0.5057 - val_loss: 1.3817 - val_accuracy: 0.5126
# Epoch 24/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3931 - accuracy: 0.5074 - val_loss: 1.3819 - val_accuracy: 0.5071
# Epoch 25/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3758 - accuracy: 0.5163 - val_loss: 1.3769 - val_accuracy: 0.5128
# Epoch 26/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3719 - accuracy: 0.5155 - val_loss: 1.3734 - val_accuracy: 0.5124
# Epoch 27/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3620 - accuracy: 0.5181 - val_loss: 1.3574 - val_accuracy: 0.5220
# Epoch 28/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3559 - accuracy: 0.5233 - val_loss: 1.3612 - val_accuracy: 0.5158
# Epoch 29/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3382 - accuracy: 0.5258 - val_loss: 1.3481 - val_accuracy: 0.5237
# Epoch 30/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3286 - accuracy: 0.5300 - val_loss: 1.3471 - val_accuracy: 0.5245
# Epoch 31/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3190 - accuracy: 0.5346 - val_loss: 1.3541 - val_accuracy: 0.5174
# Epoch 32/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.3118 - accuracy: 0.5372 - val_loss: 1.3358 - val_accuracy: 0.5284
# Epoch 33/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.3033 - accuracy: 0.5401 - val_loss: 1.3433 - val_accuracy: 0.5266
# Epoch 34/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2950 - accuracy: 0.5411 - val_loss: 1.3382 - val_accuracy: 0.5303
# Epoch 35/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2889 - accuracy: 0.5446 - val_loss: 1.3244 - val_accuracy: 0.5305
# Epoch 36/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2748 - accuracy: 0.5484 - val_loss: 1.3212 - val_accuracy: 0.5347
# Epoch 37/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2696 - accuracy: 0.5504 - val_loss: 1.3188 - val_accuracy: 0.5295
# Epoch 38/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2661 - accuracy: 0.5530 - val_loss: 1.3190 - val_accuracy: 0.5366
# Epoch 39/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2522 - accuracy: 0.5574 - val_loss: 1.3107 - val_accuracy: 0.5343
# Epoch 40/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2472 - accuracy: 0.5604 - val_loss: 1.3161 - val_accuracy: 0.5346
# Epoch 41/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2408 - accuracy: 0.5617 - val_loss: 1.3006 - val_accuracy: 0.5380
# Epoch 42/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2307 - accuracy: 0.5643 - val_loss: 1.3112 - val_accuracy: 0.5348
# Epoch 43/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2206 - accuracy: 0.5683 - val_loss: 1.3000 - val_accuracy: 0.5378
# Epoch 44/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2101 - accuracy: 0.5712 - val_loss: 1.2969 - val_accuracy: 0.5382
# Epoch 45/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.2016 - accuracy: 0.5747 - val_loss: 1.3016 - val_accuracy: 0.5404
# Epoch 46/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.1980 - accuracy: 0.5757 - val_loss: 1.2896 - val_accuracy: 0.5410
# Epoch 47/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1932 - accuracy: 0.5776 - val_loss: 1.2866 - val_accuracy: 0.5451
# Epoch 48/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1856 - accuracy: 0.5816 - val_loss: 1.2990 - val_accuracy: 0.5387
# Epoch 49/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1737 - accuracy: 0.5829 - val_loss: 1.2979 - val_accuracy: 0.5449
# Epoch 50/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1724 - accuracy: 0.5844 - val_loss: 1.2921 - val_accuracy: 0.5437
# Epoch 51/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1610 - accuracy: 0.5908 - val_loss: 1.2927 - val_accuracy: 0.5412
# Epoch 52/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1491 - accuracy: 0.5948 - val_loss: 1.2828 - val_accuracy: 0.5477
# Epoch 53/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1430 - accuracy: 0.5949 - val_loss: 1.2927 - val_accuracy: 0.5456
# Epoch 54/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1411 - accuracy: 0.5943 - val_loss: 1.2845 - val_accuracy: 0.5485
# Epoch 55/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1406 - accuracy: 0.5957 - val_loss: 1.2783 - val_accuracy: 0.5472
# Epoch 56/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1253 - accuracy: 0.6000 - val_loss: 1.2823 - val_accuracy: 0.5490
# Epoch 57/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1189 - accuracy: 0.6033 - val_loss: 1.2885 - val_accuracy: 0.5481
# Epoch 58/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1201 - accuracy: 0.6043 - val_loss: 1.2832 - val_accuracy: 0.5475
# Epoch 59/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1103 - accuracy: 0.6078 - val_loss: 1.2737 - val_accuracy: 0.5470
# Epoch 60/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.1028 - accuracy: 0.6118 - val_loss: 1.2690 - val_accuracy: 0.5525
# Epoch 61/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0991 - accuracy: 0.6092 - val_loss: 1.2697 - val_accuracy: 0.5500
# Epoch 62/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0913 - accuracy: 0.6131 - val_loss: 1.2656 - val_accuracy: 0.5521
# Epoch 63/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0866 - accuracy: 0.6152 - val_loss: 1.2685 - val_accuracy: 0.5526
# Epoch 64/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0759 - accuracy: 0.6184 - val_loss: 1.2823 - val_accuracy: 0.5445
# Epoch 65/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0704 - accuracy: 0.6198 - val_loss: 1.2647 - val_accuracy: 0.5517
# Epoch 66/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0666 - accuracy: 0.6226 - val_loss: 1.2767 - val_accuracy: 0.5500
# Epoch 67/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0590 - accuracy: 0.6240 - val_loss: 1.2709 - val_accuracy: 0.5505
# Epoch 68/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0523 - accuracy: 0.6278 - val_loss: 1.2686 - val_accuracy: 0.5544
# Epoch 69/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0472 - accuracy: 0.6293 - val_loss: 1.2686 - val_accuracy: 0.5560
# Epoch 70/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0374 - accuracy: 0.6306 - val_loss: 1.2753 - val_accuracy: 0.5496
# Epoch 71/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0312 - accuracy: 0.6319 - val_loss: 1.2738 - val_accuracy: 0.5529
# Epoch 72/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0254 - accuracy: 0.6371 - val_loss: 1.2806 - val_accuracy: 0.5531
# Epoch 73/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0310 - accuracy: 0.6335 - val_loss: 1.2750 - val_accuracy: 0.5507
# Epoch 74/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0151 - accuracy: 0.6398 - val_loss: 1.2554 - val_accuracy: 0.5599
# Epoch 75/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0083 - accuracy: 0.6398 - val_loss: 1.2787 - val_accuracy: 0.5552
# Epoch 76/100
# 98/98 [==============================] - 1s 8ms/step - loss: 1.0071 - accuracy: 0.6430 - val_loss: 1.2677 - val_accuracy: 0.5554
# Epoch 77/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9957 - accuracy: 0.6463 - val_loss: 1.2712 - val_accuracy: 0.5586
# Epoch 78/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9972 - accuracy: 0.6467 - val_loss: 1.2842 - val_accuracy: 0.5533
# Epoch 79/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9921 - accuracy: 0.6492 - val_loss: 1.2718 - val_accuracy: 0.5566
# Epoch 80/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9906 - accuracy: 0.6487 - val_loss: 1.2809 - val_accuracy: 0.5535
# Epoch 81/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9828 - accuracy: 0.6488 - val_loss: 1.2733 - val_accuracy: 0.5562
# Epoch 82/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9769 - accuracy: 0.6536 - val_loss: 1.2619 - val_accuracy: 0.5594
# Epoch 83/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9685 - accuracy: 0.6557 - val_loss: 1.2845 - val_accuracy: 0.5547
# Epoch 84/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9619 - accuracy: 0.6566 - val_loss: 1.2762 - val_accuracy: 0.5531
# Epoch 85/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9544 - accuracy: 0.6598 - val_loss: 1.2859 - val_accuracy: 0.5566
# Epoch 86/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9513 - accuracy: 0.6611 - val_loss: 1.3025 - val_accuracy: 0.5480
# Epoch 87/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9505 - accuracy: 0.6622 - val_loss: 1.2952 - val_accuracy: 0.5627
# Epoch 88/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9441 - accuracy: 0.6626 - val_loss: 1.2692 - val_accuracy: 0.5595
# Epoch 89/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9386 - accuracy: 0.6650 - val_loss: 1.2834 - val_accuracy: 0.5548
# Epoch 90/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9321 - accuracy: 0.6706 - val_loss: 1.2788 - val_accuracy: 0.5590
# Epoch 91/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9251 - accuracy: 0.6700 - val_loss: 1.2844 - val_accuracy: 0.5592
# Epoch 92/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9227 - accuracy: 0.6701 - val_loss: 1.2819 - val_accuracy: 0.5576
# Epoch 93/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.9183 - accuracy: 0.6727 - val_loss: 1.2853 - val_accuracy: 0.5566
# Epoch 94/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9097 - accuracy: 0.6776 - val_loss: 1.3011 - val_accuracy: 0.5476
# Epoch 95/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9153 - accuracy: 0.6774 - val_loss: 1.2907 - val_accuracy: 0.5540
# Epoch 96/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.8985 - accuracy: 0.6830 - val_loss: 1.2702 - val_accuracy: 0.5605
# Epoch 97/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.8990 - accuracy: 0.6808 - val_loss: 1.3112 - val_accuracy: 0.5508
# Epoch 98/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.9061 - accuracy: 0.6778 - val_loss: 1.2860 - val_accuracy: 0.5604
# Epoch 99/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.8891 - accuracy: 0.6843 - val_loss: 1.2885 - val_accuracy: 0.5618
# Epoch 100/100
# 98/98 [==============================] - 1s 8ms/step - loss: 0.8807 - accuracy: 0.6888 - val_loss: 1.2786 - val_accuracy: 0.5624

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
